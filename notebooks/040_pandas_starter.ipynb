# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130201", periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-02-01', '2013-02-02', '2013-02-03', '2013-02-04',
#                '2013-02-05', '2013-02-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

# %%
df
# Out:
#                    A         B         C         D
# 2013-02-01 -0.539171  1.597557 -0.335326 -1.761006
# 2013-02-02  0.805043 -0.954153 -0.858934  1.774166
# 2013-02-03 -0.203660 -0.750343  0.260434 -0.349140
# 2013-02-04 -0.354980  0.182839  0.845189 -0.861620
# 2013-02-05  1.055744 -1.299760 -0.710434 -1.119675
# 2013-02-06 -0.232604 -0.170354  2.550888  1.115569

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df.head(3)
# Out:
#                    A         B         C         D
# 2013-02-01 -0.539171  1.597557 -0.335326 -1.761006
# 2013-02-02  0.805043 -0.954153 -0.858934  1.774166
# 2013-02-03 -0.203660 -0.750343  0.260434 -0.349140

# %%
df.tail(2)
# Out:
#                    A         B         C         D
# 2013-02-05  1.055744 -1.299760 -0.710434 -1.119675
# 2013-02-06 -0.232604 -0.170354  2.550888  1.115569

# %%
df.index
# Out:
# DatetimeIndex(['2013-02-01', '2013-02-02', '2013-02-03', '2013-02-04',
#                '2013-02-05', '2013-02-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[-0.53917094,  1.59755661, -0.33532567, -1.76100554],
#        [ 0.80504326, -0.95415334, -0.85893435,  1.77416568],
#        [-0.2036595 , -0.75034332,  0.26043422, -0.34913987],
#        [-0.35497988,  0.18283902,  0.84518946, -0.86162043],
#        [ 1.05574431, -1.29975972, -0.71043378, -1.1196745 ],
#        [-0.23260407, -0.17035362,  2.55088788,  1.11556938]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.088396 -0.232369  0.291970 -0.200284
# std    0.667549  1.044362  1.275355  1.368983
# min   -0.539171 -1.299760 -0.858934 -1.761006
# 25%   -0.324386 -0.903201 -0.616657 -1.055161
# 50%   -0.218132 -0.460348 -0.037446 -0.605380
# 75%    0.552868  0.094541  0.699001  0.749392
# max    1.055744  1.597557  2.550888  1.774166

# %%
# transposing
df.T
# Out:
#    2013-02-01  2013-02-02  2013-02-03  2013-02-04  2013-02-05  2013-02-06
# A   -0.539171    0.805043   -0.203660   -0.354980    1.055744   -0.232604
# B    1.597557   -0.954153   -0.750343    0.182839   -1.299760   -0.170354
# C   -0.335326   -0.858934    0.260434    0.845189   -0.710434    2.550888
# D   -1.761006    1.774166   -0.349140   -0.861620   -1.119675    1.115569

# %%
df.sort_index(axis=0, ascending=True)
# Out:
#                    A         B         C         D
# 2013-02-01 -0.539171  1.597557 -0.335326 -1.761006
# 2013-02-02  0.805043 -0.954153 -0.858934  1.774166
# 2013-02-03 -0.203660 -0.750343  0.260434 -0.349140
# 2013-02-04 -0.354980  0.182839  0.845189 -0.861620
# 2013-02-05  1.055744 -1.299760 -0.710434 -1.119675
# 2013-02-06 -0.232604 -0.170354  2.550888  1.115569

# %%
df["A"]
# Out:
# 2013-02-01   -0.539171
# 2013-02-02    0.805043
# 2013-02-03   -0.203660
# 2013-02-04   -0.354980
# 2013-02-05    1.055744
# 2013-02-06   -0.232604
# Freq: D, Name: A, dtype: float64

# %%
df.A
# Out:
# 2013-02-01   -0.539171
# 2013-02-02    0.805043
# 2013-02-03   -0.203660
# 2013-02-04   -0.354980
# 2013-02-05    1.055744
# 2013-02-06   -0.232604
# Freq: D, Name: A, dtype: float64

# %%
df[["D", "A"]]
# Out:
#                    D         A
# 2013-02-01 -1.761006 -0.539171
# 2013-02-02  1.774166  0.805043
# 2013-02-03 -0.349140 -0.203660
# 2013-02-04 -0.861620 -0.354980
# 2013-02-05 -1.119675  1.055744
# 2013-02-06  1.115569 -0.232604

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-02-01 -0.539171  1.597557 -0.335326 -1.761006
# 2013-02-02  0.805043 -0.954153 -0.858934  1.774166
# 2013-02-03 -0.203660 -0.750343  0.260434 -0.349140

# %%
# select by label
df.loc[dates[0]]
# Out:
# A   -0.539171
# B    1.597557
# C   -0.335326
# D   -1.761006
# Name: 2013-02-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-02-01 -0.539171  1.597557
# 2013-02-02  0.805043 -0.954153
# 2013-02-03 -0.203660 -0.750343
# 2013-02-04 -0.354980  0.182839
# 2013-02-05  1.055744 -1.299760
# 2013-02-06 -0.232604 -0.170354

# %%
df.loc["20130202":"20130204", ["A", "B"]]
# Out:
#                    A         B
# 2013-02-02  0.805043 -0.954153
# 2013-02-03 -0.203660 -0.750343
# 2013-02-04 -0.354980  0.182839

# %%
df.loc[dates[0], "A"]
# Out:
# -0.5391709391961289

# %%
df.at[dates[0], "A"]
# Out:
# -0.5391709391961289

# %%
# by position
df.iloc[3]
# Out:
# A   -0.354980
# B    0.182839
# C    0.845189
# D   -0.861620
# Name: 2013-02-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-02-04 -0.354980  0.182839
# 2013-02-05  1.055744 -1.299760

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-02-02  0.805043 -0.858934
# 2013-02-03 -0.203660  0.260434
# 2013-02-05  1.055744 -0.710434

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-02-02  0.805043 -0.954153 -0.858934  1.774166
# 2013-02-03 -0.203660 -0.750343  0.260434 -0.349140

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-02-01  1.597557 -0.335326
# 2013-02-02 -0.954153 -0.858934
# 2013-02-03 -0.750343  0.260434
# 2013-02-04  0.182839  0.845189
# 2013-02-05 -1.299760 -0.710434
# 2013-02-06 -0.170354  2.550888

# %%
df.iloc[1, 1]
# Out:
# -0.954153344570972

# %%
df.iat[1, 1]
# Out:
# -0.954153344570972

# %%
# boolean indexing
df[df["A"] > 1]
# Out:
#                    A        B         C         D
# 2013-02-05  1.055744 -1.29976 -0.710434 -1.119675

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-02-01       NaN  1.597557       NaN       NaN
# 2013-02-02  0.805043       NaN       NaN  1.774166
# 2013-02-03       NaN       NaN  0.260434       NaN
# 2013-02-04       NaN  0.182839  0.845189       NaN
# 2013-02-05  1.055744       NaN       NaN       NaN
# 2013-02-06       NaN       NaN  2.550888  1.115569

# %%
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three"]
df2
# Out:
#                    A         B         C         D      E
# 2013-02-01 -0.539171  1.597557 -0.335326 -1.761006    one
# 2013-02-02  0.805043 -0.954153 -0.858934  1.774166    one
# 2013-02-03 -0.203660 -0.750343  0.260434 -0.349140    two
# 2013-02-04 -0.354980  0.182839  0.845189 -0.861620  three
# 2013-02-05  1.055744 -1.299760 -0.710434 -1.119675   four
# 2013-02-06 -0.232604 -0.170354  2.550888  1.115569  three

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-02-03 -0.203660 -0.750343  0.260434 -0.349140   two
# 2013-02-05  1.055744 -1.299760 -0.710434 -1.119675  four

# %%
# Setting
s1 = pd.Series(
   [1, 2, 3, 4, 5, 6],
   index=pd.date_range("20130201", periods=6))
s1
# Out:
# 2013-02-01    1
# 2013-02-02    2
# 2013-02-03    3
# 2013-02-04    4
# 2013-02-05    5
# 2013-02-06    6
# Freq: D, dtype: int64

# %%
df["F"] = s1

# %%
df
# Out:
#                    A         B         C         D  F
# 2013-02-01 -0.539171  1.597557 -0.335326 -1.761006  1
# 2013-02-02  0.805043 -0.954153 -0.858934  1.774166  2
# 2013-02-03 -0.203660 -0.750343  0.260434 -0.349140  3
# 2013-02-04 -0.354980  0.182839  0.845189 -0.861620  4
# 2013-02-05  1.055744 -1.299760 -0.710434 -1.119675  5
# 2013-02-06 -0.232604 -0.170354  2.550888  1.115569  6

# %%
# by label
df.at[dates[0], "A"] = 0

# %%
# by position
df.iat[0, 1] = 0

# %%
df.loc[:, "D"] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C    D  F
# 2013-02-01  0.000000  0.000000 -0.335326  5.0  1
# 2013-02-02  0.805043 -0.954153 -0.858934  5.0  2
# 2013-02-03 -0.203660 -0.750343  0.260434  5.0  3
# 2013-02-04 -0.354980  0.182839  0.845189  5.0  4
# 2013-02-05  1.055744 -1.299760 -0.710434  5.0  5
# 2013-02-06 -0.232604 -0.170354  2.550888  5.0  6

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C    D  F
# 2013-02-01  0.000000  0.000000 -0.335326 -5.0 -1
# 2013-02-02 -0.805043 -0.954153 -0.858934 -5.0 -2
# 2013-02-03 -0.203660 -0.750343 -0.260434 -5.0 -3
# 2013-02-04 -0.354980 -0.182839 -0.845189 -5.0 -4
# 2013-02-05 -1.055744 -1.299760 -0.710434 -5.0 -5
# 2013-02-06 -0.232604 -0.170354 -2.550888 -5.0 -6

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])
df1.loc[dates[0] : dates[1], "E"] = 1
df1
# Out:
#                    A         B         C    D  F    E
# 2013-02-01  0.000000  0.000000 -0.335326  5.0  1  1.0
# 2013-02-02  0.805043 -0.954153 -0.858934  5.0  2  1.0
# 2013-02-03 -0.203660 -0.750343  0.260434  5.0  3  NaN
# 2013-02-04 -0.354980  0.182839  0.845189  5.0  4  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C    D  F    E
# 2013-02-01  0.000000  0.000000 -0.335326  5.0  1  1.0
# 2013-02-02  0.805043 -0.954153 -0.858934  5.0  2  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C    D  F    E
# 2013-02-01  0.000000  0.000000 -0.335326  5.0  1  1.0
# 2013-02-02  0.805043 -0.954153 -0.858934  5.0  2  1.0
# 2013-02-03 -0.203660 -0.750343  0.260434  5.0  3  5.0
# 2013-02-04 -0.354980  0.182839  0.845189  5.0  4  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-02-01  False  False  False  False  False  False
# 2013-02-02  False  False  False  False  False  False
# 2013-02-03  False  False  False  False  False   True
# 2013-02-04  False  False  False  False  False   True

# %%
# Operations
df
# Out:
#                    A         B         C    D  F
# 2013-02-01  0.000000  0.000000 -0.335326  5.0  1
# 2013-02-02  0.805043 -0.954153 -0.858934  5.0  2
# 2013-02-03 -0.203660 -0.750343  0.260434  5.0  3
# 2013-02-04 -0.354980  0.182839  0.845189  5.0  4
# 2013-02-05  1.055744 -1.299760 -0.710434  5.0  5
# 2013-02-06 -0.232604 -0.170354  2.550888  5.0  6

# %%
df.mean()
# Out:
# A    0.178257
# B   -0.498628
# C    0.291970
# D    5.000000
# F    3.500000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2013-02-01    1.132935
# 2013-02-02    1.198391
# 2013-02-03    1.461286
# 2013-02-04    1.934610
# 2013-02-05    1.809110
# 2013-02-06    2.629586
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)
s
# Out:
# 2013-02-01    NaN
# 2013-02-02    NaN
# 2013-02-03    1.0
# 2013-02-04    3.0
# 2013-02-05    5.0
# 2013-02-06    NaN
# Freq: D, dtype: float64

# %%
df
# Out:
#                    A         B         C    D  F
# 2013-02-01  0.000000  0.000000 -0.335326  5.0  1
# 2013-02-02  0.805043 -0.954153 -0.858934  5.0  2
# 2013-02-03 -0.203660 -0.750343  0.260434  5.0  3
# 2013-02-04 -0.354980  0.182839  0.845189  5.0  4
# 2013-02-05  1.055744 -1.299760 -0.710434  5.0  5
# 2013-02-06 -0.232604 -0.170354  2.550888  5.0  6

# %%
df.sub(s, axis="index")
# Out:
#                    A         B         C    D    F
# 2013-02-01       NaN       NaN       NaN  NaN  NaN
# 2013-02-02       NaN       NaN       NaN  NaN  NaN
# 2013-02-03 -1.203660 -1.750343 -0.739566  4.0  2.0
# 2013-02-04 -3.354980 -2.817161 -2.154811  2.0  1.0
# 2013-02-05 -3.944256 -6.299760 -5.710434  0.0  0.0
# 2013-02-06       NaN       NaN       NaN  NaN  NaN

# %%
df
# Out:
#                    A         B         C    D  F
# 2013-02-01  0.000000  0.000000 -0.335326  5.0  1
# 2013-02-02  0.805043 -0.954153 -0.858934  5.0  2
# 2013-02-03 -0.203660 -0.750343  0.260434  5.0  3
# 2013-02-04 -0.354980  0.182839  0.845189  5.0  4
# 2013-02-05  1.055744 -1.299760 -0.710434  5.0  5
# 2013-02-06 -0.232604 -0.170354  2.550888  5.0  6

# %%
df.agg(lambda x: np.mean(x) * 5.6)
# Out:
# A     0.998241
# B    -2.792320
# C     1.635030
# D    28.000000
# F    19.600000
# dtype: float64

# %%
df.transform(lambda x: x * 101.2)
# Out:
#                      A           B           C      D      F
# 2013-02-01    0.000000    0.000000  -33.934958  506.0  101.2
# 2013-02-02   81.470378  -96.560318  -86.924156  506.0  202.4
# 2013-02-03  -20.610342  -75.934744   26.355943  506.0  303.6
# 2013-02-04  -35.923964   18.503309   85.533174  506.0  404.8
# 2013-02-05  106.841324 -131.535684  -71.895898  506.0  506.0
# 2013-02-06  -23.539532  -17.239786  258.149854  506.0  607.2

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s.value_counts()
# Out:
# 5    3
# 2    2
# 1    2
# 4    1
# 6    1
# 3    1
# Name: count, dtype: int64

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0 -1.127530 -0.188695 -0.328291 -1.006673
# 1 -2.263500  1.160088 -0.249097 -0.497348
# 2 -0.312729  0.239566  0.585685 -1.182089
# 3 -0.856057 -0.099936  0.232223  0.415402
# 4 -0.566177  1.899220  1.368897  1.083378
# 5  1.060158  0.284772  0.106066  0.001396
# 6  0.942136  0.641169  1.517295 -0.338588
# 7  0.394278  0.888796 -1.319386 -1.064403
# 8 -1.773167  1.111908 -0.035133  0.733603
# 9  0.170531 -1.875279 -1.753467 -0.946628

# %%
pieces = [df[:3], df[3:7], df[7:]]
df3 = pd.concat(pieces)
df3
# Out:
#           0         1         2         3
# 0 -1.127530 -0.188695 -0.328291 -1.006673
# 1 -2.263500  1.160088 -0.249097 -0.497348
# 2 -0.312729  0.239566  0.585685 -1.182089
# 3 -0.856057 -0.099936  0.232223  0.415402
# 4 -0.566177  1.899220  1.368897  1.083378
# 5  1.060158  0.284772  0.106066  0.001396
# 6  0.942136  0.641169  1.517295 -0.338588
# 7  0.394278  0.888796 -1.319386 -1.064403
# 8 -1.773167  1.111908 -0.035133  0.733603
# 9  0.170531 -1.875279 -1.753467 -0.946628

# %%
import matplotlib.pyplot as plt
df3[0].plot()
# Out:
# <Axes: >

# %%
path = "../data/Results.csv"
# Load CSV file
df = pd.read_csv(path)
df
# Out:
#             Label  Area     Mean  StdDev       XM       YM   Major   Minor  \
# 0    1  blobs.gif   433  190.855  30.305   20.474   13.635  33.820  16.301
# 1    2  blobs.gif   185  179.286  21.883   63.623    4.682  20.467  11.508
# 2    3  blobs.gif   658  205.617  29.381  108.931   12.983  29.917  28.004
# 3    4  blobs.gif   434  217.327  36.061  154.949   10.144  24.244  22.793
# 4    5  blobs.gif   477  212.143  29.904  247.633   13.596  30.876  19.670
# ..  ..        ...   ...      ...     ...      ...      ...     ...     ...
# 59  60  blobs.gif     1  128.000   0.000  110.500  246.500   1.128   1.128
# 60  61  blobs.gif    81  183.407  34.682  178.979  251.763  17.830   5.784
# 61  62  blobs.gif    90  181.511  25.599  128.042  251.921  21.662   5.290
# 62  63  blobs.gif    53  188.377  38.799  234.803  252.188  13.891   4.858
# 63  64  blobs.gif    49  172.898  28.743   74.168  252.523  16.336   3.819
#
#       Angle  Circ.  Median   Skew   Kurt     AR  Round  Solidity
# ...

# %%
df["Area"].describe()
# Out:
# count     64.000000
# mean     347.546875
# std      217.766289
# min        1.000000
# 25%      182.500000
# 50%      355.500000
# 75%      502.250000
# max      902.000000
# Name: Area, dtype: float64

# %%
# Keep only numeric columns
numeric_df = df.select_dtypes(include="number")

# Compute correlation matrix
corr = numeric_df.corr()

# Create plot
fig, ax = plt.subplots(figsize=(14, 12))

# Display correlation matrix
im = ax.imshow(corr, aspect='auto')

# Axis labels
ax.set_xticks(range(len(corr.columns)))
ax.set_yticks(range(len(corr.columns)))
ax.set_xticklabels(corr.columns, rotation=90)
ax.set_yticklabels(corr.columns)

# Add color bar
fig.colorbar(im)

# Title
ax.set_title("Correlation Matrix of Parameters")
# Improve layout
plt.tight_layout()

# Show plot
plt.show()

# %%
from pandas.plotting import scatter_matrix

# Keep only numeric columns
numeric_df = numeric_df.loc[:,["Mean","Circ.","Kurt","Skew"]]
# Create scatter matrix
scatter_matrix(
    numeric_df,
    figsize=(20, 20),
    diagonal='hist',
    marker='O'
    
)

# Improve layout
plt.tight_layout()

# Show plot
plt.show()

# %%
df["Shape"] = df["Circ."]<0.7

# %%
axes = df.boxplot(["Skew","Kurt"], by="Shape")
