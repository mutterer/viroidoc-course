# %%
from bioio import BioImage
img = BioImage("./../data/mitosis.tif")

# %%
type(img)

# %%
img.dims.order  # returns string "TCZYX"

# %%
stack = img.get_image_data("CZYX", T=0)

# %%
import ndv
ndv.imshow(stack)
